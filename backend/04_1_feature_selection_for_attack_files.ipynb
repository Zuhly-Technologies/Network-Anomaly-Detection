# %%
##  "attacks" folder (with attack csv files) is required for the operation of the program.
##  "attacks" folder must be located in the same directory as the program.


##  the purpose of this code is to determine which features to use in the machine learning phase.
##  for this purpose, the importance weights of the attacks are calculated.
##  this calculation was made using sklearn-RandomForestRegressor.

##  the some codes parts used for calculation and graphing are taken from the following site.
##  http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html

# import numpy as np
# import os
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline
# from sklearn.ensemble import ExtraTreesClassifier
# from sklearn.ensemble import RandomForestRegressor
# import sklearn as sk
# import time
# seconds = time.time()

# def folder(f_name): #this function creates a folder named "feaure_pics" in the program directory.
#     try:
#         if not os.path.exists(f_name):
#             os.makedirs(f_name)
#     except OSError:
#         print ("The folder could not be created!")
        

# # CSV files names:
# csv_files=os.listdir("attacks")# It creates a list of file names in the "attacks" folder.

# # Headers of column
# main_labels=["Flow Duration","Total Fwd Packets",   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
#    "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
#    "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
#    "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
#    "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
#    "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
#    "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
#    "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
#    "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
#    "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min",
#     "Idle Mean","Idle Std","Idle Max", "Idle Min","Label"]

# ths = open("importance_list_for_attack_files.csv", "w")
# folder("./feaure_pics/")
# for j in csv_files:
#     df=pd.read_csv(".\\attacks\\"+j,usecols=main_labels)
#     df=df.fillna(0)
#     attack_or_not=[]
#     for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
#         if i =="BENIGN":
#             attack_or_not.append(1)
#         else:
#             attack_or_not.append(0)           
#     df["Label"]=attack_or_not

#     y = df["Label"].values
#     del df["Label"]
#     X = df.values
    
#     X = np.float32(X)
#     X[np.isnan(X)] = 0
#     X[np.isinf(X)] = 0
   

#     #computing the feature importances
#     forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
#     forest.fit(X, y)
#     importances = forest.feature_importances_
#     std = np.std([tree.feature_importances_ for tree in forest.estimators_],
#                  axis=0)
#     indices = np.argsort(importances)[::-1]
#     refclasscol=list(df.columns.values)
#     impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
#     impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
#     plt.rcParams['figure.figsize'] = (10, 5)
#     impor_bars.plot.bar();
#     #printing the feature importances  
#     count=0
#     fea_ture=j[0:-4]+"=["
#     for i in impor_bars.index:
#         fea_ture=fea_ture+"\""+str(i)+"\","
#         count+=1
#         if count==5:
#             fea_ture=fea_ture[0:-1]+"]"
#             break     
#     print(j[0:-4],"importance list:")
#     print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
#     print(fea_ture)
#     plt.title(j[0:-4]+" Attack - Feature Importance")
#     plt.ylabel('Importance')
#     plt.savefig("./feaure_pics/"+j[0:-4]+".pdf",bbox_inches='tight', format = 'pdf')
#     ths.write((  fea_ture ) )
#     plt.tight_layout()
#     plt.show()
#     print("-----------------------------------------------------------------------------------------------\n\n\n\n")

    
# print("mission accomplished!")
# print("Total operation time: = ",time.time()- seconds ,"seconds")
# ths.close()

#//////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
import time

# Ensure matplotlib inline is used only in Jupyter Notebook
# %matplotlib inline

def folder(f_name):  # This function creates a folder named "feature_pics" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print("The folder could not be created!")

# Start timing
seconds = time.time()

# CSV files names:
csv_files = os.listdir("attacks")  # It creates a list of file names in the "attacks" folder.
print("CSV files to process:", csv_files)  # Debug print to check files

# Headers of column
main_labels = ["Flow Duration","Total Fwd Packets","Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets",
               "Fwd Packet Length Max","Fwd Packet Length Min","Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max",
               "Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std","Flow Bytes/s","Flow Packets/s","Flow IAT Mean",
               "Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max","Fwd IAT Min",
               "Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags",
               "Bwd URG Flags","Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length",
               "Packet Length Mean","Packet Length Std","Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count",
               "PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count","ECE Flag Count","Down/Up Ratio","Average Packet Size",
               "Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk","Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk",
               "Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes","Subflow Bwd Packets","Subflow Bwd Bytes",
               "Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd","min_seg_size_forward","Active Mean","Active Std",
               "Active Max","Active Min","Idle Mean","Idle Std","Idle Max","Idle Min","Label"]

ths = open("importance_list_for_attack_files.csv", "w")
folder("./feature_pics/")

for j in csv_files:
    file_path = os.path.join("attacks", j)
    print("Processing file:", file_path)  # Debug print to check file being processed

    try:
        df = pd.read_csv(file_path, usecols=main_labels)
        print("Read file successfully:", file_path)  # Debug print to confirm file read

        df = df.fillna(0)
        attack_or_not = []
        for i in df["Label"]:  # it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
            if i == "BENIGN":
                attack_or_not.append(1)
            else:
                attack_or_not.append(0)
        df["Label"] = attack_or_not

        y = df["Label"].values
        del df["Label"]
        X = df.values

        X = np.float32(X)
        X[np.isnan(X)] = 0
        X[np.isinf(X)] = 0

        # computing the feature importances
        forest = RandomForestRegressor(n_estimators=250, random_state=0)
        forest.fit(X, y)
        importances = forest.feature_importances_
        std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
        indices = np.argsort(importances)[::-1]
        refclasscol = list(df.columns.values)
        impor_bars = pd.DataFrame({'Features': refclasscol[0:20], 'importance': importances[0:20]})
        impor_bars = impor_bars.sort_values('importance', ascending=False).set_index('Features')
        plt.rcParams['figure.figsize'] = (10, 5)
        impor_bars.plot.bar()

        # printing the feature importances  
        count = 0
        fea_ture = j[0:-4] + "=["
        for i in impor_bars.index:
            fea_ture = fea_ture + "\"" + str(i) + "\","
            count += 1
            if count == 5:
                fea_ture = fea_ture[0:-1] + "]"
                break

        print(j[0:-4], "importance list:")
        print(j[0:-4], "\n", impor_bars.head(20), "\n\n\n")
        print(fea_ture)

        plt.title(j[0:-4] + " Attack - Feature Importance")
        plt.ylabel('Importance')
        plt.savefig(os.path.join("feature_pics", j[0:-4] + ".pdf"), bbox_inches='tight', format='pdf')
        ths.write(fea_ture)
        plt.tight_layout()
        plt.show()
        print("-----------------------------------------------------------------------------------------------\n\n\n\n")
    except Exception as e:
        print("Failed to process file:", file_path)
        print(e)

print("Total operation time: = ", time.time() - seconds, "seconds")
ths.close()
# Out:
# CSV files to process: ['Web Attack.csv', 'SSH-Patator.csv', 'DoS Slowhttptest.csv', 'Infiltration.csv', 'DoS Hulk.csv', 'PortScan.csv', 'Bot.csv', 'DoS slowloris.csv', 'DDoS.csv', 'Heartbleed.csv', 'FTP-Patator.csv', 'DoS GoldenEye.csv']
# Processing file: attacks/Web Attack.csv
# Read file successfully: attacks/Web Attack.csv
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Flow Duration                       0.0
# Total Fwd Packets                   0.0
# Total Backward Packets              0.0
# Total Length of Fwd Packets         0.0
# Total Length of Bwd Packets         0.0
# Fwd Packet Length Max               0.0
# Fwd Packet Length Min               0.0
# Fwd Packet Length Mean              0.0
# Fwd Packet Length Std               0.0
# Bwd Packet Length Max               0.0
# Bwd Packet Length Min               0.0
# Bwd Packet Length Mean              0.0
# Bwd Packet Length Std               0.0
# Flow Bytes/s                        0.0
# Flow Packets/s                      0.0
# Flow IAT Mean                       0.0
# Flow IAT Std                        0.0
# Flow IAT Max                        0.0
# Flow IAT Min                        0.0
# Fwd IAT Total                       0.0
#
#
#
# Web Attack=["Flow Duration","Total Fwd Packets","Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/SSH-Patator.csv
# Read file successfully: attacks/SSH-Patator.csv
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Flow Bytes/s                   0.000985
# Flow IAT Std                   0.000764
# Total Length of Fwd Packets    0.000605
# Flow Duration                  0.000586
# Flow IAT Mean                  0.000527
# Flow IAT Max                   0.000445
# Fwd Packet Length Std          0.000408
# Fwd IAT Total                  0.000372
# Fwd Packet Length Max          0.000330
# Bwd Packet Length Std          0.000326
# Flow Packets/s                 0.000292
# Fwd Packet Length Mean         0.000284
# Flow IAT Min                   0.000258
# Total Length of Bwd Packets    0.000253
# Total Backward Packets         0.000155
# Bwd Packet Length Max          0.000145
# Bwd Packet Length Mean         0.000142
# Total Fwd Packets              0.000131
# Fwd Packet Length Min          0.000053
# Bwd Packet Length Min          0.000037
#
#
#
# SSH-Patator=["Flow Bytes/s","Flow IAT Std","Total Length of Fwd Packets","Flow Duration","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/DoS Slowhttptest.csv
# Read file successfully: attacks/DoS Slowhttptest.csv
# DoS Slowhttptest importance list:
# DoS Slowhttptest
#                               importance
# Features
# Flow IAT Mean                  0.645993
# Fwd Packet Length Min          0.103988
# Bwd Packet Length Max          0.020161
# Total Length of Bwd Packets    0.015697
# Bwd Packet Length Mean         0.014362
# Fwd Packet Length Std          0.006678
# Fwd Packet Length Mean         0.005160
# Flow IAT Min                   0.004204
# Bwd Packet Length Std          0.002807
# Fwd Packet Length Max          0.001664
# Total Length of Fwd Packets    0.001422
# Bwd Packet Length Min          0.001302
# Total Backward Packets         0.000819
# Total Fwd Packets              0.000511
# Flow Duration                  0.000503
# Flow IAT Std                   0.000427
# Flow Bytes/s                   0.000393
# Flow IAT Max                   0.000278
# Fwd IAT Total                  0.000245
# Flow Packets/s                 0.000231
#
#
#
# DoS Slowhttptest=["Flow IAT Mean","Fwd Packet Length Min","Bwd Packet Length Max","Total Length of Bwd Packets","Bwd Packet Length Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/Infiltration.csv
# Read file successfully: attacks/Infiltration.csv
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Fwd IAT Total                  0.151825
# Flow Duration                  0.112548
# Fwd Packet Length Std          0.079320
# Fwd Packet Length Max          0.075797
# Bwd Packet Length Max          0.035553
# Total Backward Packets         0.031217
# Flow IAT Max                   0.030629
# Fwd Packet Length Mean         0.030277
# Bwd Packet Length Mean         0.025735
# Total Length of Fwd Packets    0.021626
# Total Fwd Packets              0.019707
# Bwd Packet Length Min          0.006148
# Bwd Packet Length Std          0.004005
# Flow IAT Std                   0.002784
# Total Length of Bwd Packets    0.001959
# Fwd Packet Length Min          0.001061
# Flow IAT Mean                  0.000680
# Flow Bytes/s                   0.000647
# Flow IAT Min                   0.000591
# Flow Packets/s                 0.000000
#
#
#
# Infiltration=["Fwd IAT Total","Flow Duration","Fwd Packet Length Std","Fwd Packet Length Max","Bwd Packet Length Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/DoS Hulk.csv
# Read file successfully: attacks/DoS Hulk.csv
# DoS Hulk importance list:
# DoS Hulk
#                               importance
# Features
# Bwd Packet Length Std          0.509112
# Fwd Packet Length Std          0.073860
# Fwd Packet Length Max          0.004111
# Flow IAT Min                   0.001469
# Flow Duration                  0.000490
# Flow Packets/s                 0.000400
# Flow IAT Mean                  0.000385
# Total Backward Packets         0.000361
# Flow IAT Max                   0.000270
# Fwd IAT Total                  0.000229
# Total Length of Fwd Packets    0.000219
# Bwd Packet Length Mean         0.000166
# Total Length of Bwd Packets    0.000144
# Flow IAT Std                   0.000081
# Total Fwd Packets              0.000048
# Flow Bytes/s                   0.000034
# Bwd Packet Length Max          0.000031
# Fwd Packet Length Mean         0.000009
# Bwd Packet Length Min          0.000004
# Fwd Packet Length Min          0.000000
#
#
#
# DoS Hulk=["Bwd Packet Length Std","Fwd Packet Length Std","Fwd Packet Length Max","Flow IAT Min","Flow Duration"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/PortScan.csv
# Read file successfully: attacks/PortScan.csv
# PortScan importance list:
# PortScan
#                                 importance
# Features
# Flow Bytes/s                 3.081916e-01
# Total Length of Fwd Packets  3.066195e-01
# Flow Duration                3.311203e-04
# Flow IAT Max                 3.035106e-04
# Flow IAT Mean                2.975282e-04
# Total Fwd Packets            7.686162e-05
# Fwd Packet Length Max        7.121616e-05
# Fwd Packet Length Mean       6.423616e-05
# Bwd Packet Length Std        6.291178e-05
# Fwd IAT Total                4.382759e-05
# Flow Packets/s               3.707013e-05
# Fwd Packet Length Std        3.283428e-05
# Total Length of Bwd Packets  2.994489e-05
# Flow IAT Min                 2.672379e-05
# Bwd Packet Length Mean       2.635506e-05
# Flow IAT Std                 2.450800e-05
# Bwd Packet Length Min        2.147537e-05
# Bwd Packet Length Max        2.083254e-05
# Total Backward Packets       6.266742e-06
# Fwd Packet Length Min        1.043836e-07
#
#
#
# PortScan=["Flow Bytes/s","Total Length of Fwd Packets","Flow Duration","Flow IAT Max","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/Bot.csv
# Read file successfully: attacks/Bot.csv
# Bot importance list:
# Bot
#                               importance
# Features
# Bwd Packet Length Mean         0.305650
# Flow Duration                  0.019638
# Flow IAT Min                   0.015509
# Flow IAT Max                   0.007005
# Flow IAT Std                   0.006119
# Flow Bytes/s                   0.004721
# Flow IAT Mean                  0.004129
# Fwd Packet Length Mean         0.002359
# Bwd Packet Length Max          0.002188
# Total Length of Bwd Packets    0.002073
# Flow Packets/s                 0.002035
# Fwd IAT Total                  0.001660
# Total Backward Packets         0.000736
# Total Length of Fwd Packets    0.000673
# Total Fwd Packets              0.000280
# Fwd Packet Length Min          0.000257
# Bwd Packet Length Std          0.000111
# Fwd Packet Length Max          0.000073
# Fwd Packet Length Std          0.000023
# Bwd Packet Length Min          0.000023
#
#
#
# Bot=["Bwd Packet Length Mean","Flow Duration","Flow IAT Min","Flow IAT Max","Flow IAT Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/DoS slowloris.csv
# Read file successfully: attacks/DoS slowloris.csv
# DoS slowloris importance list:
# DoS slowloris
#                               importance
# Features
# Bwd Packet Length Mean         0.208271
# Flow IAT Std                   0.207311
# Flow IAT Mean                  0.107222
# Fwd Packet Length Min          0.085125
# Total Length of Bwd Packets    0.004921
# Total Length of Fwd Packets    0.004115
# Fwd IAT Total                  0.003918
# Fwd Packet Length Mean         0.003875
# Fwd Packet Length Max          0.003675
# Total Fwd Packets              0.002115
# Bwd Packet Length Std          0.001596
# Flow Bytes/s                   0.001335
# Fwd Packet Length Std          0.001248
# Flow IAT Min                   0.000725
# Flow IAT Max                   0.000668
# Flow Duration                  0.000500
# Flow Packets/s                 0.000453
# Bwd Packet Length Max          0.000398
# Total Backward Packets         0.000398
# Bwd Packet Length Min          0.000288
#
#
#
# DoS slowloris=["Bwd Packet Length Mean","Flow IAT Std","Flow IAT Mean","Fwd Packet Length Min","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/DDoS.csv
# Read file successfully: attacks/DDoS.csv
# DDoS importance list:
# DDoS
#                               importance
# Features
# Bwd Packet Length Std          0.464924
# Total Backward Packets         0.086512
# Fwd IAT Total                  0.013295
# Flow Duration                  0.007349
# Flow IAT Min                   0.006498
# Flow IAT Std                   0.005350
# Flow IAT Mean                  0.005210
# Flow IAT Max                   0.004520
# Flow Bytes/s                   0.002529
# Fwd Packet Length Mean         0.002259
# Total Length of Fwd Packets    0.001920
# Fwd Packet Length Max          0.001894
# Fwd Packet Length Std          0.001418
# Flow Packets/s                 0.001082
# Bwd Packet Length Min          0.000863
# Bwd Packet Length Max          0.000736
# Bwd Packet Length Mean         0.000280
# Fwd Packet Length Min          0.000086
# Total Length of Bwd Packets    0.000083
# Total Fwd Packets              0.000063
#
#
#
# DDoS=["Bwd Packet Length Std","Total Backward Packets","Fwd IAT Total","Flow Duration","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/Heartbleed.csv
# Read file successfully: attacks/Heartbleed.csv
# Heartbleed importance list:
# Heartbleed
#                               importance
# Features
# Total Backward Packets         0.044643
# Bwd Packet Length Mean         0.044643
# Fwd IAT Total                  0.040179
# Flow Duration                  0.040179
# Bwd Packet Length Std          0.031250
# Fwd Packet Length Std          0.031250
# Total Length of Bwd Packets    0.026786
# Total Fwd Packets              0.026786
# Bwd Packet Length Max          0.026786
# Total Length of Fwd Packets    0.022321
# Fwd Packet Length Max          0.017857
# Fwd Packet Length Mean         0.013393
# Flow IAT Min                   0.013393
# Flow Bytes/s                   0.013393
# Flow IAT Std                   0.004464
# Flow IAT Mean                  0.004464
# Bwd Packet Length Min          0.000000
# Fwd Packet Length Min          0.000000
# Flow Packets/s                 0.000000
# Flow IAT Max                   0.000000
#
#
#
# Heartbleed=["Total Backward Packets","Bwd Packet Length Mean","Fwd IAT Total","Flow Duration","Bwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/FTP-Patator.csv
# Read file successfully: attacks/FTP-Patator.csv
# FTP-Patator importance list:
# FTP-Patator
#                               importance
# Features
# Fwd Packet Length Max          0.287215
# Fwd Packet Length Std          0.148675
# Fwd Packet Length Mean         0.036240
# Fwd Packet Length Min          0.000403
# Flow IAT Min                   0.000282
# Flow IAT Max                   0.000259
# Flow IAT Mean                  0.000200
# Flow Duration                  0.000196
# Fwd IAT Total                  0.000138
# Bwd Packet Length Min          0.000100
# Total Length of Bwd Packets    0.000091
# Bwd Packet Length Max          0.000080
# Total Backward Packets         0.000073
# Flow Bytes/s                   0.000064
# Total Fwd Packets              0.000061
# Bwd Packet Length Std          0.000060
# Total Length of Fwd Packets    0.000057
# Bwd Packet Length Mean         0.000046
# Flow IAT Std                   0.000039
# Flow Packets/s                 0.000037
#
#
#
# FTP-Patator=["Fwd Packet Length Max","Fwd Packet Length Std","Fwd Packet Length Mean","Fwd Packet Length Min","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Processing file: attacks/DoS GoldenEye.csv
# Read file successfully: attacks/DoS GoldenEye.csv
# DoS GoldenEye importance list:
# DoS GoldenEye
#                               importance
# Features
# Bwd Packet Length Std          0.301188
# Flow IAT Max                   0.241086
# Flow IAT Min                   0.110134
# Total Backward Packets         0.016960
# Fwd Packet Length Min          0.014976
# Flow IAT Mean                  0.010887
# Flow IAT Std                   0.007548
# Flow Packets/s                 0.002810
# Fwd Packet Length Mean         0.001897
# Total Length of Fwd Packets    0.001067
# Flow Duration                  0.001025
# Fwd Packet Length Max          0.000989
# Bwd Packet Length Mean         0.000923
# Fwd IAT Total                  0.000695
# Bwd Packet Length Max          0.000534
# Flow Bytes/s                   0.000405
# Fwd Packet Length Std          0.000247
# Total Length of Bwd Packets    0.000177
# Total Fwd Packets              0.000145
# Bwd Packet Length Min          0.000024
#
#
#
# DoS GoldenEye=["Bwd Packet Length Std","Flow IAT Max","Flow IAT Min","Total Backward Packets","Fwd Packet Length Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  647.034031867981 seconds
